# %%
import  requests, re
from requests_html import HTMLSession, HTML
session = HTMLSession()
import pandas as pd

# %%
l = []
# LP1= "lekki/lekki-phase-1"
locations = ["ikorodu"]
property_area = ["agric", "akute-ajuwon", "apeka", "ebute", "ibesh", "igbogbo", "ijede", "ikorodu", "ipakodo", "isawo", "jumofak", "maya", "odongunyan"]
for place in locations:

    r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place)

    for area in property_area:
        
        r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area)

        items = int(re.findall("\d+",r.html.find('div.property-sale-number')[0].text)[2])
        listings = 20
        pages = int(items/listings) + 1

        for page in range(pages):

            r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area+"?page="+str(page))
            properties = r.html.find('div.single-room-text')
            #base_url="https://www.propertypro.ng/property-for-rent?search="+place+ "&auto=&type=&bedroom=&max_price="
        
            for i in list(range(0,len(properties))):
                d={}
                d["location"] = place
                d["property_area"] = area
                try:
                    d["street"] = properties[i].find('h4')[0].text
                except (IndexError,TypeError,AttributeError):
                    d["location"] = None
                try:
                    d["features"]= properties[i].find('div.fur-areea')[0].text 
                except (AttributeError,IndexError) as e:
                    d["features"]= None
                try:
                    d["bed"]= int(re.findall("..bed",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bed"]= 0 
                try:
                    d["bath"]= int(re.findall("..bath",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bath"]= 0
                try:
                    d["toilet"]= int(re.findall("..Toilet",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["toilet"]= 0
                try:
                    d["description"]= properties[i].find('h3.listings-property-title2')[0].text
                except (IndexError,TypeError,AttributeError) as e:
                    d["description"]= None

                try:
                    d["price"]= properties[i].find('h3.listings-price')[0].text.replace("₦ ","").replace(",","")
                except (IndexError,TypeError,AttributeError) as e:
                    d["price"] = None
                l.append(d)

# %%
import pandas as pd
ld = pd.DataFrame(l)
ld
# Out:
#      location property_area                                          street  \
# 0     ikorodu         agric   Opeoluwa Bustop, Isawo rd,Agric Ikorodu Lagos
# 1     ikorodu         agric                        IsawoAgric Ikorodu Lagos
# 2     ikorodu         agric              Isawo bus stop Agric Ikorodu Lagos
# 3     ikorodu         agric                   Isawo RoadAgric Ikorodu Lagos
# 4     ikorodu         agric             Ogunyeye Street Agric Ikorodu Lagos
# ...       ...           ...                                             ...
# 4120  ikorodu    odongunyan          Isekalu streetOdongunyan Ikorodu Lagos
# 4121  ikorodu    odongunyan               OdogunyanOdongunyan Ikorodu Lagos
# 4122  ikorodu    odongunyan  Second gate, laspotechOdongunyan Ikorodu Lagos
# 4123  ikorodu    odongunyan           Ogijo IkoroduOdongunyan Ikorodu Lagos
# 4124  ikorodu    odongunyan               odogunyanOdongunyan Ikorodu Lagos
#
#                       features  bed  bath  toilet  \
# 0     1 beds 1 baths 2 Toilets    1     1       2
# 1     2 beds 1 baths 1 Toilets    2     1       1
# 2     2 beds 2 baths 1 Toilets    2     2       1
# 3     1 beds 1 baths 1 Toilets    1     1       1
# 4     2 beds 1 baths 1 Toilets    2     1       1
# ...                        ...  ...   ...     ...
# 4120  0 beds 0 baths 0 Toilets    0     0       0
# 4121  2 beds 2 baths 3 Toilets    2     2       3
# 4122  1 beds 1 baths 1 Toilets    1     1       1
# 4123  1 beds 1 baths 1 Toilets    1     1       1
# 4124  3 beds 3 baths 3 Toilets    3     3       3
#
#                                           description   price
# 0                Spaciously built mini flat/2bed flat  200000
# 1     2 bedroom flat - Newly Renovated 2 bedroom flat  280000
# 2               2-Bedroom for rent with nice features  280000
# 3                                           Mini-flat  220000
# 4                                      2 bedroom flat  230000
# ...                                               ...     ...
# 4120                         Decent room self contain  150000
# 4121                            Decent 2 bedroom flat  350000
# 4122                                      A room self  100000
# 4123  Ordinary room available to let in Ogijo Ikorodu   30000
# 4124                                   3 bedroom flat  400000
#
# [4125 rows x 9 columns]

# %%
ld.to_csv("House_prices_ikorodu.csv")

# %%
l = []
# LP1= "lekki/lekki-phase-1"
locations = ["gbagada"]
property_area = ["atunrase-medina", "gbagada", "ifako-gbagada", "medina", "millenuim-ups", "new-garage", "oworonshoki", "phase-1", "phase-2", "soluyi"]
for place in locations:

    r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place)

    for area in property_area:
        
        r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area)

        items = int(re.findall("\d+",r.html.find('div.property-sale-number')[0].text)[2])
        listings = 20
        pages = int(items/listings) + 1

        for page in range(pages):

            r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area+"?page="+str(page))
            properties = r.html.find('div.single-room-text')
            #base_url="https://www.propertypro.ng/property-for-rent?search="+place+ "&auto=&type=&bedroom=&max_price="
        
            for i in list(range(0,len(properties))):
                d={}
                d["location"] = place
                d["property_area"] = area
                try:
                    d["street"] = properties[i].find('h4')[0].text
                except (IndexError,TypeError,AttributeError):
                    d["location"] = None
                try:
                    d["features"]= properties[i].find('div.fur-areea')[0].text 
                except (AttributeError,IndexError) as e:
                    d["features"]= None
                try:
                    d["bed"]= int(re.findall("..bed",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bed"]= 0 
                try:
                    d["bath"]= int(re.findall("..bath",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bath"]= 0
                try:
                    d["toilet"]= int(re.findall("..Toilet",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["toilet"]= 0
                try:
                    d["description"]= properties[i].find('h3.listings-property-title2')[0].text
                except (IndexError,TypeError,AttributeError) as e:
                    d["description"]= None

                try:
                    d["price"]= properties[i].find('h3.listings-price')[0].text.replace("₦ ","").replace(",","")
                except (IndexError,TypeError,AttributeError) as e:
                    d["price"] = None
                l.append(d)

# %%
ld = pd.DataFrame(l)
ld
# Out:
#       location    property_area  \
# 0      gbagada  atunrase-medina
# 1      gbagada  atunrase-medina
# 2      gbagada  atunrase-medina
# 3      gbagada  atunrase-medina
# 4      gbagada  atunrase-medina
# ...        ...              ...
# 11008  gbagada           soluyi
# 11009  gbagada           soluyi
# 11010  gbagada           soluyi
# 11011  gbagada           soluyi
# 11012  gbagada           soluyi
#
#                                                   street  \
# 0                          Atunrase Medina Gbagada Lagos
# 1                 Atunrase Atunrase Medina Gbagada Lagos
# 2      Medina estate gbagadaAtunrase Medina Gbagada L...
# 3                          Atunrase Medina Gbagada Lagos
# 4                          Atunrase Medina Gbagada Lagos
# ...                                                  ...
# 11008  Shadia Estate behind Chevron Staff Club & Clin...
# 11009                     Powerline Soluyi Gbagada Lagos
# 11010                Josodak estate Soluyi Gbagada Lagos
# 11011                      PowerlineSoluyi Gbagada Lagos
# 11012              Sholuyi powerlineSoluyi Gbagada Lagos
#
#                        features  bed  bath  toilet  \
# 0      1 beds 1 baths 1 Toilets    1     1       1
# 1      3 beds 3 baths 3 Toilets    3     3       3
# 2      2 beds 2 baths 2 Toilets    2     2       2
# 3        3 beds 3 baths Toilets    3     3       0
# 4      2 beds 2 baths 2 Toilets    2     2       2
# ...                         ...  ...   ...     ...
# 11008  4 beds 4 baths 5 Toilets    4     4       5
# 11009  3 beds 3 baths 4 Toilets    3     3       4
# 11010  3 beds 2 baths 2 Toilets    3     2       2
# 11011  3 beds 3 baths 4 Toilets    3     3       4
# 11012  3 beds 2 baths 3 Toilets    3     2       3
#
#                                             description    price
# 0      Lovely Newly built and partly serviced mini flat   900000
# 1             Nice 3 bedroom duplex at Atunrase gbagada  2000000
# 2                            newly built 2 bedroom flat  1500000
# 3          3bedroom duplex new house in Atunrase Estate  2000000
# 4                                   BRAND NEW MINI FLAT  1400000
# ...                                                 ...      ...
# 11008                                    4 Bedroom flat  1800000
# 11009                          Luxury 3 Bedroom Ensuite  1100000
# 11010                                  A 3 Bedroom Flat   900000
# 11011                                    3 Bedroom Flat  1000000
# 11012                                    3 Bedroom flat  1000000
#
# [11013 rows x 9 columns]

# %%
ld.to_csv("House_prices_gbagada.csv")

# %%
l = []
# LP1= "lekki/lekki-phase-1"
locations = ["ajah"]
property_area = ["abijo", "abraham-adesanya-estate", "ado", "ajiran", "ajiwe", "akodo", "awoyaya", "badore", "canaan-estate", "chevron", "crown-estate", "eden-garden-estate", "graceland-estate", "ilaje", "lakowe", "lekki-gardens-estate", "off-lekki-epe-expressway", "ogombo", "okun-ajah", "olokonla", "peninsula-estate", "sangotedo", "thomas-estate"]
for place in locations:

    r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place)

    for area in property_area:
        
        r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area)

        items = int(re.findall("\d+",r.html.find('div.property-sale-number')[0].text)[2])
        listings = 20
        pages = int(items/listings) + 1

        for page in range(pages):

            r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area+"?page="+str(page))
            properties = r.html.find('div.single-room-text')
            #base_url="https://www.propertypro.ng/property-for-rent?search="+place+ "&auto=&type=&bedroom=&max_price="
        
            for i in list(range(0,len(properties))):
                d={}
                d["location"] = place
                d["property_area"] = area
                try:
                    d["street"] = properties[i].find('h4')[0].text
                except (IndexError,TypeError,AttributeError):
                    d["location"] = None
                try:
                    d["features"]= properties[i].find('div.fur-areea')[0].text 
                except (AttributeError,IndexError) as e:
                    d["features"]= None
                try:
                    d["bed"]= int(re.findall("..bed",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bed"]= 0 
                try:
                    d["bath"]= int(re.findall("..bath",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bath"]= 0
                try:
                    d["toilet"]= int(re.findall("..Toilet",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["toilet"]= 0
                try:
                    d["description"]= properties[i].find('h3.listings-property-title2')[0].text
                except (IndexError,TypeError,AttributeError) as e:
                    d["description"]= None

                try:
                    d["price"]= properties[i].find('h3.listings-price')[0].text.replace("₦ ","").replace(",","")
                except (IndexError,TypeError,AttributeError) as e:
                    d["price"] = None
                l.append(d)

# %%
ld = pd.DataFrame(l)
ld
# Out:
#      location  property_area  \
# 0        ajah          abijo
# 1        ajah          abijo
# 2        ajah          abijo
# 3        ajah          abijo
# 4        ajah          abijo
# ...       ...            ...
# 6837     ajah  thomas-estate
# 6838     ajah  thomas-estate
# 6839     ajah  thomas-estate
# 6840     ajah  thomas-estate
# 6841     ajah  thomas-estate
#
#                                                  street  \
# 0                 Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                      Abijo Ajah Lagos
# 2                   Destiny home estateAbijo Ajah Lagos
# 3                          Destiny HomeAbijo Ajah Lagos
# 4                      By Abijo G. R. AAbijo Ajah Lagos
# ...                                                 ...
# 6837  No. 15 Omoba Samshideen Street,Thomas Estate A...
# 6838                Budo estateThomas Estate Ajah Lagos
# 6839             Thomas Estate,Thomas Estate Ajah Lagos
# 6840             Thomas Estate,Thomas Estate Ajah Lagos
# 6841              Thomas estateThomas Estate Ajah Lagos
#
#                       features  bed  bath  toilet  \
# 0     7 beds 7 baths 8 Toilets    7     7       8
# 1     1 beds 1 baths 1 Toilets    1     1       1
# 2     1 beds 1 baths 1 Toilets    1     1       1
# 3     1 beds 1 baths 1 Toilets    1     1       1
# 4           beds baths Toilets    0     0       0
# ...                        ...  ...   ...     ...
# 6837  3 beds 3 baths 4 Toilets    3     3       4
# 6838  3 beds 4 baths 3 Toilets    3     4       3
# 6839  2 beds 2 baths 3 Toilets    2     2       3
# 6840  3 beds 3 baths 4 Toilets    3     3       4
# 6841  3 beds 2 baths 3 Toilets    3     2       3
#
#                                             description    price
# 0     7 bedroom fully detached house having all room...  2500000
# 1                                      Room and parlour   500000
# 2                                      Room and parlour   650000
# 3                                             Mini flat   350000
# 4     3 and Half Plots with Building for Commercial ...  2000000
# ...                                                 ...      ...
# 6837  2 Units of 3 Bedroom Semi-Detached Duplex In Ajah  2000000
# 6838                   Nice 3 bedroom detached bungalow  1200000
# 6839                             2 Bedroom Flat In Ajah  1500000
# 6840                           3 Bedroom Duplex In Ajah  1200000
# 6841  Three bedroom apartment for rent in Thomas est...   750000
#
# [6842 rows x 9 columns]

# %%
ld.to_csv("House_prices_ajah.csv")

# %%
l = []
# LP1= "lekki/lekki-phase-1"
locations = ["ikeja"]
property_area = ["adeniyi-jones", "agidingbi", "airport-road(ikeja)", "alausa", "alausa-ikeja", "allen-avenue", "awolowo-way", "balogun", "ikeja", "ikeja-g.r.a", "ikeja-gra", "mangoro", "maryland", "mobolaji-bank-anthony-way", "oba-akran", "obafemi-awolowo-way", "omole", "opebi", "oregun", "toyin-street", "unity-road"]
for place in locations:

    r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place)

    for area in property_area:
        
        r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area)

        items = int(re.findall("\d+",r.html.find('div.property-sale-number')[0].text)[2])
        listings = 20
        pages = int(items/listings) + 1

        for page in range(pages):

            r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area+"?page="+str(page))
            properties = r.html.find('div.single-room-text')
            #base_url="https://www.propertypro.ng/property-for-rent?search="+place+ "&auto=&type=&bedroom=&max_price="
        
            for i in list(range(0,len(properties))):
                d={}
                d["location"] = place
                d["property_area"] = area
                try:
                    d["street"] = properties[i].find('h4')[0].text
                except (IndexError,TypeError,AttributeError):
                    d["location"] = None
                try:
                    d["features"]= properties[i].find('div.fur-areea')[0].text 
                except (AttributeError,IndexError) as e:
                    d["features"]= None
                try:
                    d["bed"]= int(re.findall("..bed",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bed"]= 0 
                try:
                    d["bath"]= int(re.findall("..bath",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bath"]= 0
                try:
                    d["toilet"]= int(re.findall("..Toilet",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["toilet"]= 0
                try:
                    d["description"]= properties[i].find('h3.listings-property-title2')[0].text
                except (IndexError,TypeError,AttributeError) as e:
                    d["description"]= None

                try:
                    d["price"]= properties[i].find('h3.listings-price')[0].text.replace("₦ ","").replace(",","")
                except (IndexError,TypeError,AttributeError) as e:
                    d["price"] = None
                l.append(d)

# %%
ld = pd.DataFrame(l)
ld
# Out:
#       location  property_area  \
# 0        ikeja  adeniyi-jones
# 1        ikeja  adeniyi-jones
# 2        ikeja  adeniyi-jones
# 3        ikeja  adeniyi-jones
# 4        ikeja  adeniyi-jones
# ...        ...            ...
# 14397    ikeja     unity-road
# 14398    ikeja     unity-road
# 14399    ikeja     unity-road
# 14400    ikeja     unity-road
# 14401    ikeja     unity-road
#
#                                                   street  \
# 0                              Adeniyi Jones Ikeja Lagos
# 1                              Adeniyi Jones Ikeja Lagos
# 2      Geted estate adeniyi JonesAdeniyi Jones Ikeja ...
# 3      Gated estate adeniyi JonesAdeniyi Jones Ikeja ...
# 4      off adeniyi jones is in a secure closeAdeniyi ...
# ...                                                  ...
# 14397        1, John Olugbo StreetUnity Road Ikeja Lagos
# 14398         Dele Dosumu Street, Unity Road Ikeja Lagos
# 14399                 Unity StreetUnity Road Ikeja Lagos
# 14400                Unity Street Unity Road Ikeja Lagos
# 14401                Unity Street Unity Road Ikeja Lagos
#
#                        features  bed  bath  toilet  \
# 0            beds baths Toilets    0     0       0
# 1          3 beds baths Toilets    3     0       0
# 2      3 beds 4 baths 4 Toilets    3     4       4
# 3      5 beds 7 baths 7 Toilets    5     7       7
# 4      2 beds 1 baths 1 Toilets    2     1       1
# ...                         ...  ...   ...     ...
# 14397  3 beds 2 baths 2 Toilets    3     2       2
# 14398  3 beds 2 baths 3 Toilets    3     2       3
# 14399  3 beds 2 baths 2 Toilets    3     2       2
# 14400  3 beds 2 baths 2 Toilets    3     2       2
# 14401  3 beds 1 baths 1 Toilets    3     1       1
#
#                                              description     price
# 0                        110 sqm Open Plan Offices Space   3850000
# 1      Nicely Finished 5 unit of 3 bedroom flat with ...  13000000
# 2      New luxury block of 5 unit of 3bedroom for sin...  15000000
# 3       New luxury 5bedroom semi detached duplex with bq   6000000
# 4      Mini Flat with a guest room and an ample parki...    650000
# ...                                                  ...       ...
# 14397            Newly Renovated 3 Bedroom Flat in Ikeja   1200000
# 14398                                3 Bedroom Apartment   1000000
# 14399              A Nice 3 Bedroom Flat for Office Use.   1000000
# 14400                                     3 Bedroom flat   1000000
# 14401                                     3 Bedroom flat   1100000
#
# [14402 rows x 9 columns]

# %%
ld.to_csv("House_prices_ikeja.csv")

# %%
l = []
locations = ["surulere"]
property_area = ["abraham-adesanya", "adelabu", "adeniran-ogunsanya", "aguda", "alaka-estate", "alaka-iponri", "bode-thomas", "central-surulere", "coker", "eric-moore", "gbaja", "idi-araba", "ijesha", "iponri", "itire", "kilo-marsha", "lawanson", "masha", "ojuelegba", "orile-iganmu", "randle-avenue", "western-avenue"]

for place in locations:

    r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place)

    for area in property_area:
        
        r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area)

        items = int(re.findall("\d+",r.html.find('div.property-sale-number')[0].text)[2])
        listings = 20
        pages = int(items/listings) + 1

        for page in range(pages):

            r = session.get(f'https://www.propertypro.ng/property-for-rent/in/lagos/'+place+"/"+area+"?page="+str(page))
            properties = r.html.find('div.single-room-text')
            #base_url="https://www.propertypro.ng/property-for-rent?search="+place+ "&auto=&type=&bedroom=&max_price="
        
            for i in list(range(0,len(properties))):
                d={}
                d["location"] = place
                d["property_area"] = area
                try:
                    d["street"] = properties[i].find('h4')[0].text
                except (IndexError,TypeError,AttributeError):
                    d["location"] = None
                try:
                    d["features"]= properties[i].find('div.fur-areea')[0].text 
                except (AttributeError,IndexError) as e:
                    d["features"]= None
                try:
                    d["bed"]= int(re.findall("..bed",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bed"]= 0 
                try:
                    d["bath"]= int(re.findall("..bath",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["bath"]= 0
                try:
                    d["toilet"]= int(re.findall("..Toilet",properties[i].find('div.fur-areea')[0].text)[0].strip()[0][0])
                except (IndexError,TypeError,AttributeError,ValueError) as e:
                    d["toilet"]= 0
                try:
                    d["description"]= properties[i].find('h3.listings-property-title2')[0].text
                except (IndexError,TypeError,AttributeError) as e:
                    d["description"]= None

                try:
                    d["price"]= properties[i].find('h3.listings-price')[0].text.replace("₦ ","").replace(",","")
                except (IndexError,TypeError,AttributeError) as e:
                    d["price"] = None
                l.append(d)

# %%
ld = pd.DataFrame(l)
ld
# Out:
#       location     property_area  \
# 0     surulere  abraham-adesanya
# 1     surulere  abraham-adesanya
# 2     surulere  abraham-adesanya
# 3     surulere  abraham-adesanya
# 4     surulere  abraham-adesanya
# ...        ...               ...
# 4508  surulere    western-avenue
# 4509  surulere    western-avenue
# 4510  surulere    western-avenue
# 4511  surulere    western-avenue
# 4512  surulere    western-avenue
#
#                                                  street  \
# 0       Abraham AdesanyaAbraham Adesanya Surulere Lagos
# 1            main streetAbraham Adesanya Surulere Lagos
# 2                      -Abraham Adesanya Surulere Lagos
# 3     Abraham adesanya estateAbraham Adesanya Surule...
# 4     Tafawa Balewa crescent Abraham Adesanya Surule...
# ...                                                 ...
# 4508        ibidun street Western Avenue Surulere Lagos
# 4509  banire street off fashoroWestern Avenue Surule...
# 4510                     -Western Avenue Surulere Lagos
# 4511                 AllenWestern Avenue Surulere Lagos
# 4512  off Agege Motor roadWestern Avenue Surulere Lagos
#
#                       features  bed  bath  toilet  \
# 0     3 beds 4 baths 4 Toilets    3     4       4
# 1           beds baths Toilets    0     0       0
# 2     2 beds 1 baths 1 Toilets    2     1       1
# 3     3 beds 3 baths 3 Toilets    3     3       3
# 4     1 beds 0 baths 1 Toilets    1     0       1
# ...                        ...  ...   ...     ...
# 4508  3 beds 3 baths 4 Toilets    3     3       4
# 4509  3 beds 0 baths 0 Toilets    3     0       0
# 4510  2 beds 0 baths 2 Toilets    2     0       2
# 4511  1 beds 1 baths 1 Toilets    1     1       1
# 4512  1 beds 1 baths 1 Toilets    1     1       1
#
#                                             description    price
# 0     Three Bedroom Flat for Rent in Surulere, All R...   800000
# 1                                           web designs    50000
# 2                                        2 bedroom flat  1200000
# 3                             Lovely 3 bedroom bungalow  1500000
# 4                                   A Room Office Space   300000
# ...                                                 ...      ...
# 4508                                     3 BEDROOM FLAT   650000
# 4509                          3 bedroom flat (Upstairs)   700000
# 4510                                     2 BEDROOM FLAT   600000
# 4511                                   Decent Mini flat   600000
# 4512                              Newly built mini flat   400000
#
# [4513 rows x 9 columns]

# %%
ld.to_csv("House_prices_surulere.csv")

# %%
df_ajah2 = pd.read_table("House_prices_ajah.csv", sep=",", header=None)
df_ajah = pd.read_csv("House_prices_ajah.csv")

# %%
df_ajah
# Out:
#       Unnamed: 0 location  property_area  \
# 0              0     ajah          abijo
# 1              1     ajah          abijo
# 2              2     ajah          abijo
# 3              3     ajah          abijo
# 4              4     ajah          abijo
# ...          ...      ...            ...
# 6837        6837     ajah  thomas-estate
# 6838        6838     ajah  thomas-estate
# 6839        6839     ajah  thomas-estate
# 6840        6840     ajah  thomas-estate
# 6841        6841     ajah  thomas-estate
#
#                                                  street  \
# 0                 Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                      Abijo Ajah Lagos
# 2                   Destiny home estateAbijo Ajah Lagos
# 3                          Destiny HomeAbijo Ajah Lagos
# 4                      By Abijo G. R. AAbijo Ajah Lagos
# ...                                                 ...
# 6837  No. 15 Omoba Samshideen Street,Thomas Estate A...
# 6838                Budo estateThomas Estate Ajah Lagos
# 6839             Thomas Estate,Thomas Estate Ajah Lagos
# 6840             Thomas Estate,Thomas Estate Ajah Lagos
# 6841              Thomas estateThomas Estate Ajah Lagos
#
#                       features  bed  bath  toilet  \
# 0     7 beds 7 baths 8 Toilets    7     7       8
# 1     1 beds 1 baths 1 Toilets    1     1       1
# 2     1 beds 1 baths 1 Toilets    1     1       1
# 3     1 beds 1 baths 1 Toilets    1     1       1
# 4           beds baths Toilets    0     0       0
# ...                        ...  ...   ...     ...
# 6837  3 beds 3 baths 4 Toilets    3     3       4
# 6838  3 beds 4 baths 3 Toilets    3     4       3
# 6839  2 beds 2 baths 3 Toilets    2     2       3
# 6840  3 beds 3 baths 4 Toilets    3     3       4
# 6841  3 beds 2 baths 3 Toilets    3     2       3
#
#                                             description    price
# 0     7 bedroom fully detached house having all room...  2500000
# 1                                      Room and parlour   500000
# 2                                      Room and parlour   650000
# 3                                             Mini flat   350000
# 4     3 and Half Plots with Building for Commercial ...  2000000
# ...                                                 ...      ...
# 6837  2 Units of 3 Bedroom Semi-Detached Duplex In Ajah  2000000
# 6838                   Nice 3 bedroom detached bungalow  1200000
# 6839                             2 Bedroom Flat In Ajah  1500000
# 6840                           3 Bedroom Duplex In Ajah  1200000
# 6841  Three bedroom apartment for rent in Thomas est...   750000
#
# [6842 rows x 10 columns]

# %%
df_gbagada = pd.read_csv("House_prices_gbagada.csv")

# %%
df_gbagada
# Out:
#        Unnamed: 0 location    property_area  \
# 0               0  gbagada  atunrase-medina
# 1               1  gbagada  atunrase-medina
# 2               2  gbagada  atunrase-medina
# 3               3  gbagada  atunrase-medina
# 4               4  gbagada  atunrase-medina
# ...           ...      ...              ...
# 11008       11008  gbagada           soluyi
# 11009       11009  gbagada           soluyi
# 11010       11010  gbagada           soluyi
# 11011       11011  gbagada           soluyi
# 11012       11012  gbagada           soluyi
#
#                                                   street  \
# 0                          Atunrase Medina Gbagada Lagos
# 1                 Atunrase Atunrase Medina Gbagada Lagos
# 2      Medina estate gbagadaAtunrase Medina Gbagada L...
# 3                          Atunrase Medina Gbagada Lagos
# 4                          Atunrase Medina Gbagada Lagos
# ...                                                  ...
# 11008  Shadia Estate behind Chevron Staff Club & Clin...
# 11009                     Powerline Soluyi Gbagada Lagos
# 11010                Josodak estate Soluyi Gbagada Lagos
# 11011                      PowerlineSoluyi Gbagada Lagos
# 11012              Sholuyi powerlineSoluyi Gbagada Lagos
#
#                        features  bed  bath  toilet  \
# 0      1 beds 1 baths 1 Toilets    1     1       1
# 1      3 beds 3 baths 3 Toilets    3     3       3
# 2      2 beds 2 baths 2 Toilets    2     2       2
# 3        3 beds 3 baths Toilets    3     3       0
# 4      2 beds 2 baths 2 Toilets    2     2       2
# ...                         ...  ...   ...     ...
# 11008  4 beds 4 baths 5 Toilets    4     4       5
# 11009  3 beds 3 baths 4 Toilets    3     3       4
# 11010  3 beds 2 baths 2 Toilets    3     2       2
# 11011  3 beds 3 baths 4 Toilets    3     3       4
# 11012  3 beds 2 baths 3 Toilets    3     2       3
#
#                                             description      price
# 0      Lovely Newly built and partly serviced mini flat   900000.0
# 1             Nice 3 bedroom duplex at Atunrase gbagada  2000000.0
# 2                            newly built 2 bedroom flat  1500000.0
# 3          3bedroom duplex new house in Atunrase Estate  2000000.0
# 4                                   BRAND NEW MINI FLAT  1400000.0
# ...                                                 ...        ...
# 11008                                    4 Bedroom flat  1800000.0
# 11009                          Luxury 3 Bedroom Ensuite  1100000.0
# 11010                                  A 3 Bedroom Flat   900000.0
# 11011                                    3 Bedroom Flat  1000000.0
# 11012                                    3 Bedroom flat  1000000.0
#
# [11013 rows x 10 columns]

# %%
df_ikeja = pd.read_csv("House_prices_ikeja.csv")

# %%
df_ikeja
# Out:
#        Unnamed: 0 location  property_area  \
# 0               0    ikeja  adeniyi-jones
# 1               1    ikeja  adeniyi-jones
# 2               2    ikeja  adeniyi-jones
# 3               3    ikeja  adeniyi-jones
# 4               4    ikeja  adeniyi-jones
# ...           ...      ...            ...
# 14397       14397    ikeja     unity-road
# 14398       14398    ikeja     unity-road
# 14399       14399    ikeja     unity-road
# 14400       14400    ikeja     unity-road
# 14401       14401    ikeja     unity-road
#
#                                                   street  \
# 0                              Adeniyi Jones Ikeja Lagos
# 1                              Adeniyi Jones Ikeja Lagos
# 2      Geted estate adeniyi JonesAdeniyi Jones Ikeja ...
# 3      Gated estate adeniyi JonesAdeniyi Jones Ikeja ...
# 4      off adeniyi jones is in a secure closeAdeniyi ...
# ...                                                  ...
# 14397        1, John Olugbo StreetUnity Road Ikeja Lagos
# 14398         Dele Dosumu Street, Unity Road Ikeja Lagos
# 14399                 Unity StreetUnity Road Ikeja Lagos
# 14400                Unity Street Unity Road Ikeja Lagos
# 14401                Unity Street Unity Road Ikeja Lagos
#
#                        features  bed  bath  toilet  \
# 0            beds baths Toilets    0     0       0
# 1          3 beds baths Toilets    3     0       0
# 2      3 beds 4 baths 4 Toilets    3     4       4
# 3      5 beds 7 baths 7 Toilets    5     7       7
# 4      2 beds 1 baths 1 Toilets    2     1       1
# ...                         ...  ...   ...     ...
# 14397  3 beds 2 baths 2 Toilets    3     2       2
# 14398  3 beds 2 baths 3 Toilets    3     2       3
# 14399  3 beds 2 baths 2 Toilets    3     2       2
# 14400  3 beds 2 baths 2 Toilets    3     2       2
# 14401  3 beds 1 baths 1 Toilets    3     1       1
#
#                                              description     price
# 0                        110 sqm Open Plan Offices Space   3850000
# 1      Nicely Finished 5 unit of 3 bedroom flat with ...  13000000
# 2      New luxury block of 5 unit of 3bedroom for sin...  15000000
# 3       New luxury 5bedroom semi detached duplex with bq   6000000
# 4      Mini Flat with a guest room and an ample parki...    650000
# ...                                                  ...       ...
# 14397            Newly Renovated 3 Bedroom Flat in Ikeja   1200000
# 14398                                3 Bedroom Apartment   1000000
# 14399              A Nice 3 Bedroom Flat for Office Use.   1000000
# 14400                                     3 Bedroom flat   1000000
# 14401                                     3 Bedroom flat   1100000
#
# [14402 rows x 10 columns]

# %%
df_ikorodu = pd.read_csv("House_prices_ikorodu.csv")
df_LP1 = pd.read_csv("House_prices_lekki_phase1.csv")
df_surulere = pd.read_csv("House_prices_surulere.csv")
df_yaba = pd.read_csv("House_prices_yaba.csv")

# %%
House_prices_lagos = pd.concat([df_ajah, df_gbagada, df_ikeja, df_ikorodu, df_LP1, df_surulere, df_yaba ], ignore_index=True)

# %%
House_prices_lagos
# Out:
#        Unnamed: 0 location property_area  \
# 0               0     ajah         abijo
# 1               1     ajah         abijo
# 2               2     ajah         abijo
# 3               3     ajah         abijo
# 4               4     ajah         abijo
# ...           ...      ...           ...
# 65875       17534     yaba          yaba
# 65876       17535     yaba          yaba
# 65877       17536     yaba          yaba
# 65878       17537     yaba          yaba
# 65879       17538     yaba          yaba
#
#                                                   street  \
# 0                  Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 4                       By Abijo G. R. AAbijo Ajah Lagos
# ...                                                  ...
# 65875  Oshoroko Before Lacampaigne TropicanaIse Town ...
# 65876                         Second TollgateLekki Lagos
# 65877                             -Old Ikoyi Ikoyi Lagos
# 65878                                         Ajah Lagos
# 65879                               -Chevron Lekki Lagos
#
#                        features  bed  bath  toilet  \
# 0      7 beds 7 baths 8 Toilets    7     7       8
# 1      1 beds 1 baths 1 Toilets    1     1       1
# 2      1 beds 1 baths 1 Toilets    1     1       1
# 3      1 beds 1 baths 1 Toilets    1     1       1
# 4            beds baths Toilets    0     0       0
# ...                         ...  ...   ...     ...
# 65875        beds baths Toilets    0     0       0
# 65876  4 beds 4 baths 5 Toilets    4     4       5
# 65877  4 beds 4 baths 5 Toilets    4     4       5
# 65878  5 beds 6 baths 7 Toilets    5     6       7
# 65879  5 beds 6 baths 7 Toilets    5     6       7
#
#                                              description    price
# 0      7 bedroom fully detached house having all room...  2500000
# 1                                       Room and parlour   500000
# 2                                       Room and parlour   650000
# 3                                              Mini flat   350000
# 4      3 and Half Plots with Building for Commercial ...  2000000
# ...                                                  ...      ...
# 65875                      Land With CofO in Ibeju Lekki  3.3e+06
# 65876          Brand New 4 Bedroom Semi Detached Duplex;  5.7e+07
# 65877  PRINCE ADEMOLA OSINUGA OFFERS! NEWLY BUILT 4 B...  4.5e+08
# 65878  Charming Newly Built 5 Bedroom Detached House ...  7.5e+07
# 65879  Custom Built Brand New 5 Bedroom Fully Detache...  1.2e+08
#
# [65880 rows x 10 columns]

# %%
df_ajah
# Out:
#       Unnamed: 0 location  property_area  \
# 0              0     ajah          abijo
# 1              1     ajah          abijo
# 2              2     ajah          abijo
# 3              3     ajah          abijo
# 4              4     ajah          abijo
# ...          ...      ...            ...
# 6837        6837     ajah  thomas-estate
# 6838        6838     ajah  thomas-estate
# 6839        6839     ajah  thomas-estate
# 6840        6840     ajah  thomas-estate
# 6841        6841     ajah  thomas-estate
#
#                                                  street  \
# 0                 Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                      Abijo Ajah Lagos
# 2                   Destiny home estateAbijo Ajah Lagos
# 3                          Destiny HomeAbijo Ajah Lagos
# 4                      By Abijo G. R. AAbijo Ajah Lagos
# ...                                                 ...
# 6837  No. 15 Omoba Samshideen Street,Thomas Estate A...
# 6838                Budo estateThomas Estate Ajah Lagos
# 6839             Thomas Estate,Thomas Estate Ajah Lagos
# 6840             Thomas Estate,Thomas Estate Ajah Lagos
# 6841              Thomas estateThomas Estate Ajah Lagos
#
#                       features  bed  bath  toilet  \
# 0     7 beds 7 baths 8 Toilets    7     7       8
# 1     1 beds 1 baths 1 Toilets    1     1       1
# 2     1 beds 1 baths 1 Toilets    1     1       1
# 3     1 beds 1 baths 1 Toilets    1     1       1
# 4           beds baths Toilets    0     0       0
# ...                        ...  ...   ...     ...
# 6837  3 beds 3 baths 4 Toilets    3     3       4
# 6838  3 beds 4 baths 3 Toilets    3     4       3
# 6839  2 beds 2 baths 3 Toilets    2     2       3
# 6840  3 beds 3 baths 4 Toilets    3     3       4
# 6841  3 beds 2 baths 3 Toilets    3     2       3
#
#                                             description    price
# 0     7 bedroom fully detached house having all room...  2500000
# 1                                      Room and parlour   500000
# 2                                      Room and parlour   650000
# 3                                             Mini flat   350000
# 4     3 and Half Plots with Building for Commercial ...  2000000
# ...                                                 ...      ...
# 6837  2 Units of 3 Bedroom Semi-Detached Duplex In Ajah  2000000
# 6838                   Nice 3 bedroom detached bungalow  1200000
# 6839                             2 Bedroom Flat In Ajah  1500000
# 6840                           3 Bedroom Duplex In Ajah  1200000
# 6841  Three bedroom apartment for rent in Thomas est...   750000
#
# [6842 rows x 10 columns]

# %%
df_gbagada
# Out:
#        Unnamed: 0 location    property_area  \
# 0               0  gbagada  atunrase-medina
# 1               1  gbagada  atunrase-medina
# 2               2  gbagada  atunrase-medina
# 3               3  gbagada  atunrase-medina
# 4               4  gbagada  atunrase-medina
# ...           ...      ...              ...
# 11008       11008  gbagada           soluyi
# 11009       11009  gbagada           soluyi
# 11010       11010  gbagada           soluyi
# 11011       11011  gbagada           soluyi
# 11012       11012  gbagada           soluyi
#
#                                                   street  \
# 0                          Atunrase Medina Gbagada Lagos
# 1                 Atunrase Atunrase Medina Gbagada Lagos
# 2      Medina estate gbagadaAtunrase Medina Gbagada L...
# 3                          Atunrase Medina Gbagada Lagos
# 4                          Atunrase Medina Gbagada Lagos
# ...                                                  ...
# 11008  Shadia Estate behind Chevron Staff Club & Clin...
# 11009                     Powerline Soluyi Gbagada Lagos
# 11010                Josodak estate Soluyi Gbagada Lagos
# 11011                      PowerlineSoluyi Gbagada Lagos
# 11012              Sholuyi powerlineSoluyi Gbagada Lagos
#
#                        features  bed  bath  toilet  \
# 0      1 beds 1 baths 1 Toilets    1     1       1
# 1      3 beds 3 baths 3 Toilets    3     3       3
# 2      2 beds 2 baths 2 Toilets    2     2       2
# 3        3 beds 3 baths Toilets    3     3       0
# 4      2 beds 2 baths 2 Toilets    2     2       2
# ...                         ...  ...   ...     ...
# 11008  4 beds 4 baths 5 Toilets    4     4       5
# 11009  3 beds 3 baths 4 Toilets    3     3       4
# 11010  3 beds 2 baths 2 Toilets    3     2       2
# 11011  3 beds 3 baths 4 Toilets    3     3       4
# 11012  3 beds 2 baths 3 Toilets    3     2       3
#
#                                             description      price
# 0      Lovely Newly built and partly serviced mini flat   900000.0
# 1             Nice 3 bedroom duplex at Atunrase gbagada  2000000.0
# 2                            newly built 2 bedroom flat  1500000.0
# 3          3bedroom duplex new house in Atunrase Estate  2000000.0
# 4                                   BRAND NEW MINI FLAT  1400000.0
# ...                                                 ...        ...
# 11008                                    4 Bedroom flat  1800000.0
# 11009                          Luxury 3 Bedroom Ensuite  1100000.0
# 11010                                  A 3 Bedroom Flat   900000.0
# 11011                                    3 Bedroom Flat  1000000.0
# 11012                                    3 Bedroom flat  1000000.0
#
# [11013 rows x 10 columns]

# %%
df_ikeja
# Out:
#        Unnamed: 0 location  property_area  \
# 0               0    ikeja  adeniyi-jones
# 1               1    ikeja  adeniyi-jones
# 2               2    ikeja  adeniyi-jones
# 3               3    ikeja  adeniyi-jones
# 4               4    ikeja  adeniyi-jones
# ...           ...      ...            ...
# 14397       14397    ikeja     unity-road
# 14398       14398    ikeja     unity-road
# 14399       14399    ikeja     unity-road
# 14400       14400    ikeja     unity-road
# 14401       14401    ikeja     unity-road
#
#                                                   street  \
# 0                              Adeniyi Jones Ikeja Lagos
# 1                              Adeniyi Jones Ikeja Lagos
# 2      Geted estate adeniyi JonesAdeniyi Jones Ikeja ...
# 3      Gated estate adeniyi JonesAdeniyi Jones Ikeja ...
# 4      off adeniyi jones is in a secure closeAdeniyi ...
# ...                                                  ...
# 14397        1, John Olugbo StreetUnity Road Ikeja Lagos
# 14398         Dele Dosumu Street, Unity Road Ikeja Lagos
# 14399                 Unity StreetUnity Road Ikeja Lagos
# 14400                Unity Street Unity Road Ikeja Lagos
# 14401                Unity Street Unity Road Ikeja Lagos
#
#                        features  bed  bath  toilet  \
# 0            beds baths Toilets    0     0       0
# 1          3 beds baths Toilets    3     0       0
# 2      3 beds 4 baths 4 Toilets    3     4       4
# 3      5 beds 7 baths 7 Toilets    5     7       7
# 4      2 beds 1 baths 1 Toilets    2     1       1
# ...                         ...  ...   ...     ...
# 14397  3 beds 2 baths 2 Toilets    3     2       2
# 14398  3 beds 2 baths 3 Toilets    3     2       3
# 14399  3 beds 2 baths 2 Toilets    3     2       2
# 14400  3 beds 2 baths 2 Toilets    3     2       2
# 14401  3 beds 1 baths 1 Toilets    3     1       1
#
#                                              description     price
# 0                        110 sqm Open Plan Offices Space   3850000
# 1      Nicely Finished 5 unit of 3 bedroom flat with ...  13000000
# 2      New luxury block of 5 unit of 3bedroom for sin...  15000000
# 3       New luxury 5bedroom semi detached duplex with bq   6000000
# 4      Mini Flat with a guest room and an ample parki...    650000
# ...                                                  ...       ...
# 14397            Newly Renovated 3 Bedroom Flat in Ikeja   1200000
# 14398                                3 Bedroom Apartment   1000000
# 14399              A Nice 3 Bedroom Flat for Office Use.   1000000
# 14400                                     3 Bedroom flat   1000000
# 14401                                     3 Bedroom flat   1100000
#
# [14402 rows x 10 columns]

# %%
df_ikorodu
# Out:
#       Unnamed: 0 location property_area  \
# 0              0  ikorodu         agric
# 1              1  ikorodu         agric
# 2              2  ikorodu         agric
# 3              3  ikorodu         agric
# 4              4  ikorodu         agric
# ...          ...      ...           ...
# 4120        4120  ikorodu    odongunyan
# 4121        4121  ikorodu    odongunyan
# 4122        4122  ikorodu    odongunyan
# 4123        4123  ikorodu    odongunyan
# 4124        4124  ikorodu    odongunyan
#
#                                               street  \
# 0      Opeoluwa Bustop, Isawo rd,Agric Ikorodu Lagos
# 1                           IsawoAgric Ikorodu Lagos
# 2                 Isawo bus stop Agric Ikorodu Lagos
# 3                      Isawo RoadAgric Ikorodu Lagos
# 4                Ogunyeye Street Agric Ikorodu Lagos
# ...                                              ...
# 4120          Isekalu streetOdongunyan Ikorodu Lagos
# 4121               OdogunyanOdongunyan Ikorodu Lagos
# 4122  Second gate, laspotechOdongunyan Ikorodu Lagos
# 4123           Ogijo IkoroduOdongunyan Ikorodu Lagos
# 4124               odogunyanOdongunyan Ikorodu Lagos
#
#                       features  bed  bath  toilet  \
# 0     1 beds 1 baths 2 Toilets    1     1       2
# 1     2 beds 1 baths 1 Toilets    2     1       1
# 2     2 beds 2 baths 1 Toilets    2     2       1
# 3     1 beds 1 baths 1 Toilets    1     1       1
# 4     2 beds 1 baths 1 Toilets    2     1       1
# ...                        ...  ...   ...     ...
# 4120  0 beds 0 baths 0 Toilets    0     0       0
# 4121  2 beds 2 baths 3 Toilets    2     2       3
# 4122  1 beds 1 baths 1 Toilets    1     1       1
# 4123  1 beds 1 baths 1 Toilets    1     1       1
# 4124  3 beds 3 baths 3 Toilets    3     3       3
#
#                                           description     price
# 0                Spaciously built mini flat/2bed flat  200000.0
# 1     2 bedroom flat - Newly Renovated 2 bedroom flat  280000.0
# 2               2-Bedroom for rent with nice features  280000.0
# 3                                           Mini-flat  220000.0
# 4                                      2 bedroom flat  230000.0
# ...                                               ...       ...
# 4120                         Decent room self contain  150000.0
# 4121                            Decent 2 bedroom flat  350000.0
# 4122                                      A room self  100000.0
# 4123  Ordinary room available to let in Ogijo Ikorodu   30000.0
# 4124                                   3 bedroom flat  400000.0
#
# [4125 rows x 10 columns]

# %%
df_LP1
# Out:
#       Unnamed: 0 location  property_area  \
# 0              0    lekki  lekki-phase-1
# 1              1    lekki  lekki-phase-1
# 2              2    lekki  lekki-phase-1
# 3              3    lekki  lekki-phase-1
# 4              4    lekki  lekki-phase-1
# ...          ...      ...            ...
# 7441        7441    lekki  lekki-phase-1
# 7442        7442    lekki  lekki-phase-1
# 7443        7443    lekki  lekki-phase-1
# 7444        7444    lekki  lekki-phase-1
# 7445        7445    lekki  lekki-phase-1
#
#                                                 street  \
# 0             off Freedom WayLekki Phase 1 Lekki Lagos
# 1     Lekki phase Lekki LagosLekki Phase 1 Lekki Lagos
# 2                Oniru EstateLekki Phase 1 Lekki Lagos
# 3                Oniru EstateLekki Phase 1 Lekki Lagos
# 4                            Lekki Phase 1 Lekki Lagos
# ...                                                ...
# 7441              lekki rightLekki Phase 1 Lekki Lagos
# 7442       Off Hakeem DicksonLekki Phase 1 Lekki Lagos
# 7443                             Victoria Island Lagos
# 7444            Cottage DriveLekki Phase 1 Lekki Lagos
# 7445         Anthony EtukuborLekki Phase 1 Lekki Lagos
#
#                       features  bed  bath  toilet  \
# 0           beds baths Toilets    0     0       0
# 1     3 beds 3 baths 4 Toilets    3     3       4
# 2     0 beds 0 baths 0 Toilets    0     0       0
# 3     4 beds 4 baths 5 Toilets    4     4       5
# 4     3 beds 3 baths 4 Toilets    3     3       4
# ...                        ...  ...   ...     ...
# 7441  2 beds 2 baths 3 Toilets    2     2       3
# 7442  4 beds 4 baths 4 Toilets    4     4       4
# 7443    5 beds 5 baths Toilets    5     5       0
# 7444  3 beds 3 baths 4 Toilets    3     3       4
# 7445  4 beds 0 baths 0 Toilets    4     0       0
#
#                                             description    price
# 0     A Massive Serviced Duplex with 48 office seat ...    50000
# 1                        3 Bedroom semi detached duplex  3500000
# 2                                   commercial property    35000
# 3     Newly Built, Tastefully Finished Four (4) Bedr...  5000000
# 4     Decent 3-Bedroom Apartment with Swimming Pool ...  2600000
# ...                                                 ...      ...
# 7441                          2 and 3 bedroom apartment  4000000
# 7442                    4 bedroom Duplex with a room BQ  3500000
# 7443                       Luxury Smart 5bedroom duplex      NaN
# 7444                                     3 Bedroom Flat  3500000
# 7445                          4 Bedroom Detached Duplex  3500000
#
# [7446 rows x 10 columns]

# %%
df_surulere
# Out:
#       Unnamed: 0  location     property_area  \
# 0              0  surulere  abraham-adesanya
# 1              1  surulere  abraham-adesanya
# 2              2  surulere  abraham-adesanya
# 3              3  surulere  abraham-adesanya
# 4              4  surulere  abraham-adesanya
# ...          ...       ...               ...
# 4508        4508  surulere    western-avenue
# 4509        4509  surulere    western-avenue
# 4510        4510  surulere    western-avenue
# 4511        4511  surulere    western-avenue
# 4512        4512  surulere    western-avenue
#
#                                                  street  \
# 0       Abraham AdesanyaAbraham Adesanya Surulere Lagos
# 1            main streetAbraham Adesanya Surulere Lagos
# 2                      -Abraham Adesanya Surulere Lagos
# 3     Abraham adesanya estateAbraham Adesanya Surule...
# 4     Tafawa Balewa crescent Abraham Adesanya Surule...
# ...                                                 ...
# 4508        ibidun street Western Avenue Surulere Lagos
# 4509  banire street off fashoroWestern Avenue Surule...
# 4510                     -Western Avenue Surulere Lagos
# 4511                 AllenWestern Avenue Surulere Lagos
# 4512  off Agege Motor roadWestern Avenue Surulere Lagos
#
#                       features  bed  bath  toilet  \
# 0     3 beds 4 baths 4 Toilets    3     4       4
# 1           beds baths Toilets    0     0       0
# 2     2 beds 1 baths 1 Toilets    2     1       1
# 3     3 beds 3 baths 3 Toilets    3     3       3
# 4     1 beds 0 baths 1 Toilets    1     0       1
# ...                        ...  ...   ...     ...
# 4508  3 beds 3 baths 4 Toilets    3     3       4
# 4509  3 beds 0 baths 0 Toilets    3     0       0
# 4510  2 beds 0 baths 2 Toilets    2     0       2
# 4511  1 beds 1 baths 1 Toilets    1     1       1
# 4512  1 beds 1 baths 1 Toilets    1     1       1
#
#                                             description    price
# 0     Three Bedroom Flat for Rent in Surulere, All R...   800000
# 1                                           web designs    50000
# 2                                        2 bedroom flat  1200000
# 3                             Lovely 3 bedroom bungalow  1500000
# 4                                   A Room Office Space   300000
# ...                                                 ...      ...
# 4508                                     3 BEDROOM FLAT   650000
# 4509                          3 bedroom flat (Upstairs)   700000
# 4510                                     2 BEDROOM FLAT   600000
# 4511                                   Decent Mini flat   600000
# 4512                              Newly built mini flat   400000
#
# [4513 rows x 10 columns]

# %%
df_yaba
# Out:
#        Unnamed: 0 location property_area  \
# 0               0     yaba  abule-ijesha
# 1               1     yaba  abule-ijesha
# 2               2     yaba  abule-ijesha
# 3               3     yaba  abule-ijesha
# 4               4     yaba  abule-ijesha
# ...           ...      ...           ...
# 17534       17534     yaba          yaba
# 17535       17535     yaba          yaba
# 17536       17536     yaba          yaba
# 17537       17537     yaba          yaba
# 17538       17538     yaba          yaba
#
#                                                   street  \
# 0      Abuleijesha yaba down yaba tech Abule Ijesha Y...
# 1      Abuleijesha ,close to Morroco Yabatech area Ab...
# 2               Yabatech BackgateAbule Ijesha Yaba Lagos
# 3                                Abule Ijesha Yaba Lagos
# 4                    Abule ijeshaAbule Ijesha Yaba Lagos
# ...                                                  ...
# 17534  Oshoroko Before Lacampaigne TropicanaIse Town ...
# 17535                         Second TollgateLekki Lagos
# 17536                             -Old Ikoyi Ikoyi Lagos
# 17537                                         Ajah Lagos
# 17538                               -Chevron Lekki Lagos
#
#                        features  bed  bath  toilet  \
# 0      2 beds 2 baths 2 Toilets    2     2       2
# 1      1 beds 2 baths 2 Toilets    1     2       2
# 2      1 beds 1 baths 1 Toilets    1     1       1
# 3      1 beds 1 baths 1 Toilets    1     1       1
# 4      2 beds 2 baths 3 Toilets    2     2       3
# ...                         ...  ...   ...     ...
# 17534        beds baths Toilets    0     0       0
# 17535  4 beds 4 baths 5 Toilets    4     4       5
# 17536  4 beds 4 baths 5 Toilets    4     4       5
# 17537  5 beds 6 baths 7 Toilets    5     6       7
# 17538  5 beds 6 baths 7 Toilets    5     6       7
#
#                                              description        price
# 0                                     2bedroom apartment     700000.0
# 1            Standard newly built clean Miniflat at Yaba     600000.0
# 2      Newly Built Room self contain At Yabatech Back...    6000000.0
# 3                        Newly built blocks of mini flat     450000.0
# 4                    Standard newly built 2 bedroom flat     700000.0
# ...                                                  ...          ...
# 17534                      Land With CofO in Ibeju Lekki    3300000.0
# 17535          Brand New 4 Bedroom Semi Detached Duplex;   57000000.0
# 17536  PRINCE ADEMOLA OSINUGA OFFERS! NEWLY BUILT 4 B...  449999999.0
# 17537  Charming Newly Built 5 Bedroom Detached House ...   75000000.0
# 17538  Custom Built Brand New 5 Bedroom Fully Detache...  120000000.0
#
# [17539 rows x 10 columns]

# %%
House_prices_lagos = pd.concat([df_ajah, df_gbagada, df_ikeja, df_ikorodu, df_LP1, df_surulere, df_yaba ], ignore_index=True)

# %%
House_prices_lagos
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 65875     yaba          yaba
# 65876     yaba          yaba
# 65877     yaba          yaba
# 65878     yaba          yaba
# 65879     yaba          yaba
#
#                                                   street  \
# 0                  Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 4                       By Abijo G. R. AAbijo Ajah Lagos
# ...                                                  ...
# 65875  Oshoroko Before Lacampaigne TropicanaIse Town ...
# 65876                         Second TollgateLekki Lagos
# 65877                             -Old Ikoyi Ikoyi Lagos
# 65878                                         Ajah Lagos
# 65879                               -Chevron Lekki Lagos
#
#                        features  bed  bath  toilet  \
# 0      7 beds 7 baths 8 Toilets    7     7       8
# 1      1 beds 1 baths 1 Toilets    1     1       1
# 2      1 beds 1 baths 1 Toilets    1     1       1
# 3      1 beds 1 baths 1 Toilets    1     1       1
# 4            beds baths Toilets    0     0       0
# ...                         ...  ...   ...     ...
# 65875        beds baths Toilets    0     0       0
# 65876  4 beds 4 baths 5 Toilets    4     4       5
# 65877  4 beds 4 baths 5 Toilets    4     4       5
# 65878  5 beds 6 baths 7 Toilets    5     6       7
# 65879  5 beds 6 baths 7 Toilets    5     6       7
#
#                                              description    price
# 0      7 bedroom fully detached house having all room...  2500000
# 1                                       Room and parlour   500000
# 2                                       Room and parlour   650000
# 3                                              Mini flat   350000
# 4      3 and Half Plots with Building for Commercial ...  2000000
# ...                                                  ...      ...
# 65875                      Land With CofO in Ibeju Lekki  3.3e+06
# 65876          Brand New 4 Bedroom Semi Detached Duplex;  5.7e+07
# 65877  PRINCE ADEMOLA OSINUGA OFFERS! NEWLY BUILT 4 B...  4.5e+08
# 65878  Charming Newly Built 5 Bedroom Detached House ...  7.5e+07
# 65879  Custom Built Brand New 5 Bedroom Fully Detache...  1.2e+08
#
# [65880 rows x 9 columns]

# %%
House_prices_lagos.to_csv("House_prices_lagos_7.csv", index=False)
