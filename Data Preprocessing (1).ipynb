# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("House_prices_lagos_7.csv", low_memory=False)

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 65875     yaba          yaba
# 65876     yaba          yaba
# 65877     yaba          yaba
# 65878     yaba          yaba
# 65879     yaba          yaba
#
#                                                   street  \
# 0                  Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 4                       By Abijo G. R. AAbijo Ajah Lagos
# ...                                                  ...
# 65875  Oshoroko Before Lacampaigne TropicanaIse Town ...
# 65876                         Second TollgateLekki Lagos
# 65877                             -Old Ikoyi Ikoyi Lagos
# ...

# %%
df.columns
# Out:
# Index(['location', 'property_area', 'street', 'features', 'bed', 'bath',
#        'toilet', 'description', 'price'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 bed          bath        toilet
# count  65880.000000  65880.000000  65880.000000
# mean       2.453916      2.368215      2.830237
# std        1.779706      1.852374      2.204133
# min        0.000000      0.000000      0.000000
# 25%        1.000000      1.000000      1.000000
# 50%        3.000000      2.000000      3.000000
# 75%        4.000000      4.000000      5.000000
# max        9.000000      9.000000      9.000000

# %%
df.median()
# Out:
# bed       3.0
# bath      2.0
# toilet    3.0
# dtype: float64

# %%
df.dtypes
# Out:
# location         object
# property_area    object
# street           object
# features         object
# bed               int64
# bath              int64
# toilet            int64
# description      object
# price            object
# dtype: object

# %%
df.isnull()
# Out:
#        location  property_area  street  features    bed   bath  toilet  \
# 0         False          False   False     False  False  False   False
# 1         False          False   False     False  False  False   False
# 2         False          False   False     False  False  False   False
# 3         False          False   False     False  False  False   False
# 4         False          False   False     False  False  False   False
# ...         ...            ...     ...       ...    ...    ...     ...
# 65875     False          False   False     False  False  False   False
# 65876     False          False   False     False  False  False   False
# 65877     False          False   False     False  False  False   False
# 65878     False          False   False     False  False  False   False
# 65879     False          False   False     False  False  False   False
#
#        description  price
# 0            False  False
# 1            False  False
# 2            False  False
# ...

# %%
df.isna()
# Out:
#        location  property_area  street  features    bed   bath  toilet  \
# 0         False          False   False     False  False  False   False
# 1         False          False   False     False  False  False   False
# 2         False          False   False     False  False  False   False
# 3         False          False   False     False  False  False   False
# 4         False          False   False     False  False  False   False
# ...         ...            ...     ...       ...    ...    ...     ...
# 65875     False          False   False     False  False  False   False
# 65876     False          False   False     False  False  False   False
# 65877     False          False   False     False  False  False   False
# 65878     False          False   False     False  False  False   False
# 65879     False          False   False     False  False  False   False
#
#        description  price
# 0            False  False
# 1            False  False
# 2            False  False
# ...

# %%
df.isnull().sum()
# Out:
# location            0
# property_area       0
# street              0
# features            0
# bed                 0
# bath                0
# toilet              0
# description         0
# price            4281
# dtype: int64

# %%
df["bed"].argmax()
# Out:
# 14953

# %%
df["price"].max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c2b3c807469a> in <module>
# ----> 1 df["price"].max()
#
# D:\ProgramFiles\anaconda3\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11215             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11216         return self._reduce(
# > 11217             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11218         )
#   11219
#
# D:\ProgramFiles\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ...

# %%
df["price"] = df["price"].str.replace("$", "").replace(" ", "").astype(float)

# %%
df["price"]
# Out:
# 0          2500000.0
# 1           500000.0
# 2           650000.0
# 3           350000.0
# 4          2000000.0
#             ...
# 65875      3300000.0
# 65876     57000000.0
# 65877    449999999.0
# 65878     75000000.0
# 65879    120000000.0
# Name: price, Length: 65880, dtype: float64

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 65875     yaba          yaba
# 65876     yaba          yaba
# 65877     yaba          yaba
# 65878     yaba          yaba
# 65879     yaba          yaba
#
#                                                   street  \
# 0                  Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 4                       By Abijo G. R. AAbijo Ajah Lagos
# ...                                                  ...
# 65875  Oshoroko Before Lacampaigne TropicanaIse Town ...
# 65876                         Second TollgateLekki Lagos
# 65877                             -Old Ikoyi Ikoyi Lagos
# ...

# %%
df.describe()
# Out:
#                 bed          bath        toilet         price
# count  65880.000000  65880.000000  65880.000000  6.159900e+04
# mean       2.453916      2.368215      2.830237  9.029429e+09
# std        1.779706      1.852374      2.204133  1.494729e+11
# min        0.000000      0.000000      0.000000  0.000000e+00
# 25%        1.000000      1.000000      1.000000  8.000000e+05
# 50%        3.000000      2.000000      3.000000  2.500000e+06
# 75%        4.000000      4.000000      5.000000  2.900000e+07
# max        9.000000      9.000000      9.000000  2.500000e+12

# %%
df[df['price'].isnull()]['location'].value_counts()
# Out:
# yaba        1250
# ikeja       1036
# gbagada      788
# lekki        355
# ajah         326
# ikorodu      308
# surulere     218
# Name: location, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65880 entries, 0 to 65879
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location       65880 non-null  object
#  1   property_area  65880 non-null  object
#  2   street         65880 non-null  object
#  3   features       65880 non-null  object
#  4   bed            65880 non-null  int64
#  5   bath           65880 non-null  int64
#  6   toilet         65880 non-null  int64
#  7   description    65880 non-null  object
#  8   price          61599 non-null  float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 4.5+ MB

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap="viridis")

# %%
nan_values = df[pd.isnull(df.price)]
nan_values
# Out:
#       location property_area  \
# 9         ajah         abijo
# 30        ajah         abijo
# 51        ajah         abijo
# 72        ajah         abijo
# 93        ajah         abijo
# ...        ...           ...
# 65824     yaba          yaba
# 65836     yaba          yaba
# 65846     yaba          yaba
# 65858     yaba          yaba
# 65868     yaba          yaba
#
#                                                   street  \
# 9                ... Mojisola Onikoyi Estate Ikoyi Lagos
# 30     Lekki Second toll gate After Orchid Hotel Road...
# 51                             ... Old Ikoyi Ikoyi Lagos
# 72                       Ikeja Gra Ikeja GRA Ikeja Lagos
# 93                                 Victoria Island Lagos
# ...                                                  ...
# 65824                        happyland estate Ajah Lagos
# 65836                      ... Lekki Phase 1 Lekki Lagos
# 65846            ... Mojisola Onikoyi Estate Ikoyi Lagos
# ...

# %%
nan_values.count()
# Out:
# location         4281
# property_area    4281
# street           4281
# features         4281
# bed              4281
# bath             4281
# toilet           4281
# description      4281
# price               0
# dtype: int64

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 65875     yaba          yaba
# 65876     yaba          yaba
# 65877     yaba          yaba
# 65878     yaba          yaba
# 65879     yaba          yaba
#
#                                                   street  \
# 0                  Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 4                       By Abijo G. R. AAbijo Ajah Lagos
# ...                                                  ...
# 65875  Oshoroko Before Lacampaigne TropicanaIse Town ...
# 65876                         Second TollgateLekki Lagos
# 65877                             -Old Ikoyi Ikoyi Lagos
# ...

# %%
df["price"].value_counts(dropna=False)
# Out:
# NaN            4281
# 4000000.0      2528
# 400000.0       2467
# 130000000.0    2393
# 1000000.0      2141
#                ...
# 485300.0          1
# 67500000.0        1
# 38000000.0        1
# 192000000.0       1
# 320000000.0       1
# Name: price, Length: 487, dtype: int64

# %%
df["price"].nunique()
# Out:
# 486

# %%
df["bed"].value_counts(dropna=False)
# Out:
# 0    13373
# 4    13264
# 3    12208
# 1     9485
# 2     9351
# 5     5605
# 6     2457
# 7       82
# 8       39
# 9       16
# Name: bed, dtype: int64

# %%
df[df["bed"] == 0]
# Out:
#       location property_area  \
# 4         ajah         abijo
# 12        ajah         abijo
# 16        ajah         abijo
# 30        ajah         abijo
# 36        ajah         abijo
# ...        ...           ...
# 65862     yaba          yaba
# 65864     yaba          yaba
# 65865     yaba          yaba
# 65868     yaba          yaba
# 65875     yaba          yaba
#
#                                                   street  \
# 4                       By Abijo G. R. AAbijo Ajah Lagos
# 12                             Abijo GRAAbijo Ajah Lagos
# 16                                 AbijoAbijo Ajah Lagos
# 30     Lekki Second toll gate After Orchid Hotel Road...
# 36                       PALMSBAY ESTATEAbijo Ajah Lagos
# ...                                                  ...
# 65862  Oshoroko, lekki free trade ZoneFree Trade Zone...
# 65864                  Free Trade Zone Ibeju Lekki Lagos
# 65865                                Alaro CityEpe Lagos
# ...

# %%
df[56333:]
# Out:
#       location property_area  \
# 56333     yaba          yaba
# 56334     yaba          yaba
# 56335     yaba          yaba
# 56336     yaba          yaba
# 56337     yaba          yaba
# ...        ...           ...
# 65875     yaba          yaba
# 65876     yaba          yaba
# 65877     yaba          yaba
# 65878     yaba          yaba
# 65879     yaba          yaba
#
#                                                   street  \
# 56333     3 Minutes Drive From OrchidChevron Lekki Lagos
# 56334  Few meters from the Catholic MonasteryMonaster...
# 56335  Few meters from the Catholic MonasteryMonaster...
# 56336  Oshoroko, lekki free trade ZoneFree Trade Zone...
# 56337  Inside a fully Resident EstateBogije Sangotedo...
# ...                                                  ...
# 65875  Oshoroko Before Lacampaigne TropicanaIse Town ...
# 65876                         Second TollgateLekki Lagos
# 65877                             -Old Ikoyi Ikoyi Lagos
# ...

# %%
df.drop(df[56333:].index, inplace=True)

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 56328     yaba          yaba
# 56329     yaba          yaba
# 56330     yaba          yaba
# 56331     yaba          yaba
# 56332     yaba          yaba
#
#                                                   street  \
# 0                  Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 4                       By Abijo G. R. AAbijo Ajah Lagos
# ...                                                  ...
# 56328                              -Alagomeji Yaba Lagos
# 56329  In a Gated, Serene & Serviced Estate, Adekunle...
# 56330  By Commercial Avenue, Sabo, Yaba ( Close to Oz...
# ...

# %%
df.drop(df[df["bed"] == 0].index, inplace=True)

# %%
df

# %%
df.reset_index(inplace=True)

# %%
df

# %%
df["description"]
# Out:
# 0        7 bedroom fully detached house having all room...
# 1                                         Room and parlour
# 2                                         Room and parlour
# 3                                                Mini flat
# 5                                        4 bedrooms duplex
#                                ...
# 56325    Lovely Luxurious 2 Bedroom all rooms ensuite flat
# 56326    Luxurious 3 Bedroom all rooms ensuite flat (Up...
# 56329                        Executive 3 Bedroom Flat + Bq
# 56330    Spacious 3 Bedroom flat for Office or Resident...
# 56332                Luxury Smart 5 Bedroom Detached House
# Name: description, Length: 46088, dtype: object

# %%
df["description"].str.contains('Office')

# %%
df["description"].str.lower().str.contains("office")

# %%
df["description"].str.lower().str.contains("office").sum()

# %%
df[df["description"].str.lower().str.contains("office")]

# %%
df.drop(df[df["description"].str.lower().str.contains("office")].index, inplace=True)

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 5         ajah         abijo
# ...        ...           ...
# 56324     yaba          yaba
# 56325     yaba          yaba
# 56326     yaba          yaba
# 56329     yaba          yaba
# 56332     yaba          yaba
#
#                                                   street  \
# 0                  Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 5                           Amity estateAbijo Ajah Lagos
# ...                                                  ...
# 56324                              Fola Agoro Yaba Lagos
# 56325               Alagomeji, Yaba.Alagomeji Yaba Lagos
# 56326                Alagomeji-Adekunle, Yaba.Yaba Lagos
# ...

# %%
df["description"].str.lower().str.contains("commercial property")

# %%
df["description"].str.lower().str.contains("commercial property").sum()

# %%
df[df["description"].str.lower().str.contains("commercial property")]

# %%
df.drop(df[df["description"].str.lower().str.contains("commercial property")].index, inplace=True)

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 5         ajah         abijo
# ...        ...           ...
# 56324     yaba          yaba
# 56325     yaba          yaba
# 56326     yaba          yaba
# 56329     yaba          yaba
# 56332     yaba          yaba
#
#                                                   street  \
# 0                  Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 5                           Amity estateAbijo Ajah Lagos
# ...                                                  ...
# 56324                              Fola Agoro Yaba Lagos
# 56325               Alagomeji, Yaba.Alagomeji Yaba Lagos
# 56326                Alagomeji-Adekunle, Yaba.Yaba Lagos
# ...

# %%
df.reset_index(inplace=True)

# %%
df

# %%
df["bed"].value_counts(dropna=False)

# %%
df[df["bed"] > 4]
# Out:
#       location property_area                                   street  \
# 0         ajah         abijo    Abijo GRA, Ajah LagosAbijo Ajah Lagos
# 9         ajah         abijo  ... Mojisola Onikoyi Estate Ikoyi Lagos
# 44        ajah         abijo                        -Abijo Ajah Lagos
# 54        ajah         abijo  Abijo GRA, Lekki, LagosAbijo Ajah Lagos
# 57        ajah         abijo                         Abijo Ajah Lagos
# ...        ...           ...                                      ...
# 56152     yaba          sabo                     OnikeSabo Yaba Lagos
# 56153     yaba          sabo                     OnikeSabo Yaba Lagos
# 56203     yaba          sabo  Lekki Phase 1 Lekki Phase 1 Lekki Lagos
# 56320     yaba          yaba                   ... Ilasan Lekki Lagos
# 56332     yaba          yaba            ... Lekki Phase 1 Lekki Lagos
#
#                        features  bed  bath  toilet  \
# 0      7 beds 7 baths 8 Toilets    7     7       8
# ...

# %%
df.drop(df[df["bed"] > 4].index, inplace=True)

# %%
df
# Out:
#       location property_area  \
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 5         ajah         abijo
# 6         ajah         abijo
# ...        ...           ...
# 56323     yaba          yaba
# 56324     yaba          yaba
# 56325     yaba          yaba
# 56326     yaba          yaba
# 56329     yaba          yaba
#
#                                                   street  \
# 1                                       Abijo Ajah Lagos
# 2                    Destiny home estateAbijo Ajah Lagos
# 3                           Destiny HomeAbijo Ajah Lagos
# 5                           Amity estateAbijo Ajah Lagos
# 6                            Amty estateAbijo Ajah Lagos
# ...                                                  ...
# 56323                               Alagomeji Yaba Lagos
# 56324                              Fola Agoro Yaba Lagos
# 56325               Alagomeji, Yaba.Alagomeji Yaba Lagos
# ...

# %%
df["bed"].value_counts(dropna=False)
# Out:
# 3    11808
# 4     9688
# 1     9217
# 2     8728
# Name: bed, dtype: int64

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 39436     yaba          yaba
# 39437     yaba          yaba
# 39438     yaba          yaba
# 39439     yaba          yaba
# 39440     yaba          yaba
#
#                                                   street  \
# 0                                       Abijo Ajah Lagos
# 1                    Destiny home estateAbijo Ajah Lagos
# 2                           Destiny HomeAbijo Ajah Lagos
# 3                           Amity estateAbijo Ajah Lagos
# 4                            Amty estateAbijo Ajah Lagos
# ...                                                  ...
# 39436                               Alagomeji Yaba Lagos
# 39437                              Fola Agoro Yaba Lagos
# 39438               Alagomeji, Yaba.Alagomeji Yaba Lagos
# ...

# %%
df[df["price"] > 16000000]
# Out:
#       location property_area  \
# 39        ajah         abijo
# 41        ajah         abijo
# 57        ajah         abijo
# 98        ajah         abijo
# 105       ajah         abijo
# ...        ...           ...
# 65874     yaba          yaba
# 65876     yaba          yaba
# 65877     yaba          yaba
# 65878     yaba          yaba
# 65879     yaba          yaba
#
#                                                   street  \
# 39     Directly on Lekki-Epe Expressway, MajekAbijo A...
# 41                                      Abijo Ajah Lagos
# 57                                      Abijo Ajah Lagos
# 98     block 8, Government scheme (GRA) - 876sqmAbijo...
# 105                                AbijoAbijo Ajah Lagos
# ...                                                  ...
# 65874                                  Ikate Lekki Lagos
# 65876                         Second TollgateLekki Lagos
# 65877                             -Old Ikoyi Ikoyi Lagos
# ...

# %%
df.to_csv("optimized_data.csv", index=False)

# %%
df[df['price'].isnull()]['bed'].value_counts()
# Out:
# 4    1004
# 3     681
# 1     330
# 2     109
# Name: bed, dtype: int64

# %%
df[df['price'].isnull()]['location'].value_counts()
# Out:
# ikeja       640
# gbagada     504
# lekki       236
# yaba        231
# ajah        194
# ikorodu     184
# surulere    135
# Name: location, dtype: int64

# %%
df.groupby("property_area").agg({"price": np.median})
# Out:
#                              price
# property_area
# abijo                     600000.0
# abraham-adesanya         1200000.0
# abraham-adesanya-estate  1000000.0
# abule-ijesha              450000.0
# abule-oja                 400000.0
# ...                            ...
# thomas-estate            1000000.0
# toyin-street             1200000.0
# unity-road               1000000.0
# western-avenue            650000.0
# yaba                     1400000.0
#
# [101 rows x 1 columns]

# %%
df.groupby(['location','property_area','bed'])['price'].median()#.reset_index().sort_values('price')
# Out:
# location  property_area            bed
# ajah      abijo                    1       360000.0
#                                    2       600000.0
#                                    3       900000.0
#                                    4      1500000.0
#           abraham-adesanya-estate  1       400000.0
#                                             ...
# yaba      tejuosho                 3       875000.0
#                                    4      3000000.0
#           yaba                     1      1000000.0
#                                    2      1500000.0
#                                    3      1800000.0
# Name: price, Length: 377, dtype: float64

# %%
median_price = df.groupby(['location','property_area','bed'])['price'].median().reset_index()

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 39436     yaba          yaba
# 39437     yaba          yaba
# 39438     yaba          yaba
# 39439     yaba          yaba
# 39440     yaba          yaba
#
#                                                   street  \
# 0                                       Abijo Ajah Lagos
# 1                    Destiny home estateAbijo Ajah Lagos
# 2                           Destiny HomeAbijo Ajah Lagos
# 3                           Amity estateAbijo Ajah Lagos
# 4                            Amty estateAbijo Ajah Lagos
# ...                                                  ...
# 39436                               Alagomeji Yaba Lagos
# 39437                              Fola Agoro Yaba Lagos
# 39438               Alagomeji, Yaba.Alagomeji Yaba Lagos
# ...

# %%
df["key"] = df["location"] + df["property_area"] + df["bed"].astype(str)

# %%
df
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 39436     yaba          yaba
# 39437     yaba          yaba
# 39438     yaba          yaba
# 39439     yaba          yaba
# 39440     yaba          yaba
#
#                                                   street  \
# 0                                       Abijo Ajah Lagos
# 1                    Destiny home estateAbijo Ajah Lagos
# 2                           Destiny HomeAbijo Ajah Lagos
# 3                           Amity estateAbijo Ajah Lagos
# 4                            Amty estateAbijo Ajah Lagos
# ...                                                  ...
# 39436                               Alagomeji Yaba Lagos
# 39437                              Fola Agoro Yaba Lagos
# 39438               Alagomeji, Yaba.Alagomeji Yaba Lagos
# ...

# %%
median_price["key"] = median_price["location"] + median_price["property_area"] + median_price["bed"].astype(str)

# %%
median_price[median_price["property_area"] == "badore"]
# Out:
#    location property_area  bed      price          key
# 22     ajah        badore    1   400000.0  ajahbadore1
# 23     ajah        badore    2   750000.0  ajahbadore2
# 24     ajah        badore    3   900000.0  ajahbadore3
# 25     ajah        badore    4  1600000.0  ajahbadore4

# %%
median_price = median_price.drop(["location", "property_area", "bed"],axis=1)
median_price.columns = ["median_price", "key"]
median_price.head()
# Out:
#    median_price                           key
# 0      360000.0                    ajahabijo1
# 1      600000.0                    ajahabijo2
# 2      900000.0                    ajahabijo3
# 3     1500000.0                    ajahabijo4
# 4      400000.0  ajahabraham-adesanya-estate1

# %%
median_price.columns = ["median_price", "key"]

# %%
median_price
# Out:
#      median_price         key
# 0    2.000000e+06  ajahabijo0
# 1    3.600000e+05  ajahabijo1
# 2    6.000000e+05  ajahabijo2
# 3    9.000000e+05  ajahabijo3
# 4    1.500000e+06  ajahabijo4
# ..            ...         ...
# 660  3.000000e+07   yabayaba2
# 661  1.550000e+06   yabayaba3
# 662  4.600000e+07   yabayaba4
# 663  1.300000e+08   yabayaba5
# 664  1.400000e+09   yabayaba6
#
# [665 rows x 2 columns]

# %%
df2 = pd.merge(df,median_price, on ="key", how = "left")
df2
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 39436     yaba          yaba
# 39437     yaba          yaba
# 39438     yaba          yaba
# 39439     yaba          yaba
# 39440     yaba          yaba
#
#                                                   street  \
# 0                                       Abijo Ajah Lagos
# 1                    Destiny home estateAbijo Ajah Lagos
# 2                           Destiny HomeAbijo Ajah Lagos
# 3                           Amity estateAbijo Ajah Lagos
# 4                            Amty estateAbijo Ajah Lagos
# ...                                                  ...
# 39436                               Alagomeji Yaba Lagos
# 39437                              Fola Agoro Yaba Lagos
# 39438               Alagomeji, Yaba.Alagomeji Yaba Lagos
# ...

# %%
df2["new_price"] = df2["price"]
df2["new_price"][df["price"].isnull()] = df2["median_price"]
# Out:
# D:\ProgramFiles\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2[df2["new_price"].isnull()]
# Out:
#       location property_area  \
# 14328    ikeja  alausa-ikeja
# 15114    ikeja         ikeja
# 15168    ikeja         ikeja
# 15185    ikeja         ikeja
# 15333    ikeja         ikeja
# ...        ...           ...
# 32941     yaba  abule-ijesha
# 32974     yaba  abule-ijesha
# 32994     yaba  abule-ijesha
# 33031     yaba  abule-ijesha
# 33139     yaba  abule-ijesha
#
#                                                   street  \
# 14328    Off orchid road lekki Lekki Phase 2 Lekki Lagos
# 15114  Taiye Olowu Street Off Victoria Arobieke. Lekk...
# 15168                              Ikorodu Ikorodu Lagos
# 15185                              Ikorodu Ikorodu Lagos
# 15333  Taiye Olowu Street Off Victoria Arobieke. Lekk...
# ...                                                  ...
# 32941                          Lekki Phase 1 Lekki Lagos
# 32974    Off orchid road lekki Lekki Phase 2 Lekki Lagos
# 32994                                Ologolo Lekki Lagos
# ...

# %%
df2
# Out:
#       location property_area  \
# 0         ajah         abijo
# 1         ajah         abijo
# 2         ajah         abijo
# 3         ajah         abijo
# 4         ajah         abijo
# ...        ...           ...
# 39436     yaba          yaba
# 39437     yaba          yaba
# 39438     yaba          yaba
# 39439     yaba          yaba
# 39440     yaba          yaba
#
#                                                   street  \
# 0                                       Abijo Ajah Lagos
# 1                    Destiny home estateAbijo Ajah Lagos
# 2                           Destiny HomeAbijo Ajah Lagos
# 3                           Amity estateAbijo Ajah Lagos
# 4                            Amty estateAbijo Ajah Lagos
# ...                                                  ...
# 39436                               Alagomeji Yaba Lagos
# 39437                              Fola Agoro Yaba Lagos
# 39438               Alagomeji, Yaba.Alagomeji Yaba Lagos
# ...
